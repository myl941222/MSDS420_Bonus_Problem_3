# %% [markdown]
# <div class="alert alert-info">
#
#
# # 2020 US Presidential Candidates on Twitter
#
# <br>
# <br>
#
#
#
# **Author:** Atef Bader, PhD
#
# **Last Edit:** 3/1/2021
# <br>
#
#
# <br>
# </div>

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Source: https://en.wikipedia.org/wiki/2020_United_States_presidential_election

# %% [markdown]
# ### Objective

# %% [markdown]
# Learn how to connect to social media network (we will use Twitter as example in this assignment), and collect/preprocess/analyze its data
#
#
# Tweets Data Can be used for different purposes by the candidates campaigns. Below is a sample list of examples where candidates twitter accounts and tweets can be used:
#     1. Use TwitterAPI in Python to view followers and friends for 2016 Presidential Candidates
#     2. Use TwitterAPI in Python to view hot-topics and what can be trending among candidates and friends
#     3. Use TwitterAPI in Python to view what Sunday Talk Shows most followed by the candidates
#     4. Perform Sentiment Analysis of the candidate's position toward a person, socail/political issue, place, country, etc.
#
#
#
# Candidates (republicans and democrates) have differents accounts on Twitter but does the number of Twitter followers equal number of supporters for the inidividual candidates?
#
#
#
# Which Presidential Candidate has the biggest number of Twitter Followers?
#
# For a list of screen-names for 2020 presidential candidates, please access C-SPAN on Twitter at the following URL:
# __[CSPAN](https://twitter.com/cspan/lists/presidential-candidates/members?lang=en)__
#
# Who’s Running for President in 2020?
# __[NYTIMES Article](https://www.nytimes.com/interactive/2019/us/politics/2020-presidential-candidates.html)__

# %% [markdown]
# ### Installation and Setup

# %% [raw]
# For this assignment you need to do the following setup first:
#
# 1.  Install  Python package  TwitterAPI.
#     pip install TwitterAPI
#
# 2.  Create an account on twitter.com. Documentations available at the following URL:
#     https://developer.twitter.com/en/docs/basics/developer-portal/overview
#
#
# 3.  Generate authentication tokens by following the instructions here :
#     https://developer.twitter.com/en/docs/basics/authentication/guides/access-tokens
#
# 4.  Add your tokens to the credentials.txt file.

# %%
pip install TwitterAPI
# Out:
# Collecting TwitterAPI
#   Downloading TwitterAPI-2.7.3.tar.gz (11 kB)
# Requirement already satisfied: requests in c:\users\myl94\anaconda3\lib\site-packages (from TwitterAPI) (2.22.0)
# Requirement already satisfied: requests_oauthlib in c:\users\myl94\anaconda3\lib\site-packages (from TwitterAPI) (1.3.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\myl94\anaconda3\lib\site-packages (from requests->TwitterAPI) (1.25.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\myl94\anaconda3\lib\site-packages (from requests->TwitterAPI) (2019.11.28)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\myl94\anaconda3\lib\site-packages (from requests->TwitterAPI) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\myl94\anaconda3\lib\site-packages (from requests->TwitterAPI) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\myl94\anaconda3\lib\site-packages (from requests_oauthlib->TwitterAPI) (3.1.0)
# Building wheels for collected packages: TwitterAPI
#   Building wheel for TwitterAPI (setup.py): started
#   Building wheel for TwitterAPI (setup.py): finished with status 'done'
#   Created wheel for TwitterAPI: filename=TwitterAPI-2.7.3-py3-none-any.whl size=13596 sha256=98dcabf7b6d78e590f27574171780779fff11e1d90c22d9a9f3a72423c6253eb
#   Stored in directory: c:\users\myl94\appdata\local\pip\cache\wheels\c6\30\d9\6adcac41fe79f8eaa0a7ed2e99ecc519641a34fd5c1c3cbfba
# Successfully built TwitterAPI
# Installing collected packages: TwitterAPI
# Successfully installed TwitterAPI-2.7.3
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <div class="alert alert-info">
#
# ### Please make a note of the following error.
#
# You will get the following error if you attempt to run your script multiple times
# and you exceed the number of calls permitted by Twitter
#
# <BR>
#
# </div>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Twitter API

# %% [raw]
# Twitter API
#
# Two APIs:
#
#     REST API: Submit HTTP requests to access specific information (tweets, friends, ...)
#     Streaming API: Open a continuous connection to Twitter to receive real-time data.
#
# These APIs are  HTTP GET request
#
#
#
#
# Here are the twitter API docs that you must familiarize yourself with
#
# https://dev.twitter.com/rest/reference/get/followers/ids
#
# https://dev.twitter.com/overview/api/twitter-libraries

# %% [raw]
# When you search in a text (tweets are text messages), often you need to be aware of something STOP WORDS.
# You could read more about stop-words here:
#
#     https://en.wikipedia.org/wiki/Stop_words

# %% [markdown]
# # Lets create twitter object and use its API. Code snippets below will show you how to use this API

# %%
#from TwitterAPI import TwitterAPI, TwitterOAuth, TwitterRestPager

from TwitterAPI import TwitterAPI, TwitterOAuth

# %%
o = TwitterOAuth.read_file('credentials.txt')

# %%
o.access_token_key
# Out:
# 'Add-Your-Key-Here'

# %%
# Using OAuth1...
twitter = TwitterAPI(o.consumer_key,
                 o.consumer_secret,
                 o.access_token_key,
                 o.access_token_secret)

# %%
help(twitter)
# Out:
# Help on TwitterAPI in module TwitterAPI.TwitterAPI object:
#
# class TwitterAPI(builtins.object)
#  |  TwitterAPI(consumer_key=None, consumer_secret=None, access_token_key=None, access_token_secret=None, auth_type=<OAuthType.OAUTH1: 'oAuth1'>, proxy_url=None, api_version='1.1')
#  |
#  |  Access REST API or Streaming API resources.
#  |
#  |  :param consumer_key: Twitter application consumer key
#  |  :param consumer_secret: Twitter application consumer secret
#  |  :param access_token_key: Twitter application access token key
#  |  :param access_token_secret: Twitter application access token secret
#  |  :param auth_type: "oAuth1" (default) or "oAuth2"
#  |  :param proxy_url: HTTPS proxy URL string (ex. 'https://USER:PASSWORD@SERVER:PORT'),
#  |                    or dict of URLs (ex. {'http':'http://SERVER', 'https':'https://SERVER'})
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, consumer_key=None, consumer_secret=None, access_token_key=None, access_token_secret=None, auth_type=<OAuthType.OAUTH1: 'oAuth1'>, proxy_url=None, api_version='1.1')
#  |      Initialize with your Twitter application credentials
#  |
#  |  request(self, resource, params=None, files=None, method_override=None, hydrate_type=<HydrateType.NONE: 0>)
#  |      Request a Twitter REST API or Streaming API resource.
#  |
#  |      :param resource: A Twitter endpoint (ex. "search/tweets")
#  |      :param params: Dictionary with endpoint parameters or None (default)
#  |      :param files: Dictionary with multipart-encoded file or None (default)
#  |      :param method_override: Request method to override or None (default)
#  |      :param hydrate_type: HydrateType or int
#  |                           Do not hydrate - NONE or 0 (default)
#  |                           Append new field with '_hydrate' suffix with hydrate values - APPEND or 1
#  |                           Replace current field value with hydrate values - REPLACE or 2
#  |
#  |      :returns: TwitterResponse
#  |      :raises: TwitterConnectionError
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  CONNECTION_TIMEOUT = 5
#  |
#  |  REST_TIMEOUT = 5
#  |
#  |  STREAMING_TIMEOUT = 90
#  |
#  |  USER_AGENT = 'python-TwitterAPI'

# %%
# What can we do with this twitter object?
# builtin method `dir` tells us...
dir(twitter)
# Out:
# ['CONNECTION_TIMEOUT',
#  'REST_TIMEOUT',
#  'STREAMING_TIMEOUT',
#  'USER_AGENT',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_get_endpoint',
#  '_prepare_url',
#  'auth',
#  'proxies',
#  'request',
#  'version']

# %%
twitter.auth

# %%
# Get help on the `request` method using the builtin method called...`help`
help(twitter.request)
# Out:
# Help on method request in module TwitterAPI.TwitterAPI:
#
# request(resource, params=None, files=None, method_override=None, hydrate_type=<HydrateType.NONE: 0>) method of TwitterAPI.TwitterAPI.TwitterAPI instance
#     Request a Twitter REST API or Streaming API resource.
#
#     :param resource: A Twitter endpoint (ex. "search/tweets")
#     :param params: Dictionary with endpoint parameters or None (default)
#     :param files: Dictionary with multipart-encoded file or None (default)
#     :param method_override: Request method to override or None (default)
#     :param hydrate_type: HydrateType or int
#                          Do not hydrate - NONE or 0 (default)
#                          Append new field with '_hydrate' suffix with hydrate values - APPEND or 1
#                          Replace current field value with hydrate values - REPLACE or 2
#
#     :returns: TwitterResponse
#     :raises: TwitterConnectionError

# %%
# Let's start by querying the search API
response = twitter.request('search/tweets', {'q': 'big+data'})

# %%
# What object is returned?
# builtin type method will tell us.

print(type(response))
# Out:
# <class 'TwitterAPI.TwitterAPI.TwitterResponse'>

# %%
dir(response)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'close',
#  'get_iterator',
#  'get_quota',
#  'headers',
#  'json',
#  'options',
#  'response',
#  'status_code',
#  'text']

# %%
response.json
# Out:
# <bound method TwitterResponse.json of <TwitterAPI.TwitterAPI.TwitterResponse object at 0x000001EA7408B488>>

# %%
response.status_code
# See https://dev.twitter.com/overview/api/response-codes
# Out:
# 401

# %%
tweets = [r for r in response]
# Out:
# ---------------------------------------------------------------------------
# TwitterRequestError                       Traceback (most recent call last)
# <ipython-input-16-e2954f4843db> in <module>
# ----> 1 tweets = [r for r in response]
#
# ~\anaconda3\lib\site-packages\TwitterAPI\TwitterAPI.py in __iter__(self)
#     280         :raises: TwitterConnectionError, TwitterRequestError
#     281         """
# --> 282         return self.get_iterator()
#     283
#     284     def get_quota(self):
#
# ~\anaconda3\lib\site-packages\TwitterAPI\TwitterAPI.py in get_iterator(self)
#     267         """
#     268         if self.response.status_code != 200:
# --> 269             raise TwitterRequestError(self.response.status_code, msg=self.response.text)
#     270
#     271         if self.options['is_stream']:
#
# TwitterRequestError: ('{"errors":[{"code":89,"message":"Invalid or expired token."}]}',) (401): {"errors":[{"code":89,"message":"Invalid or expired token."}]}

# %%
print('found %d tweets' % len(tweets))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-a9ae73e0b8cd> in <module>
# ----> 1 print('found %d tweets' % len(tweets))
#
# NameError: name 'tweets' is not defined

# %%
type(tweets)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-b646f2611234> in <module>
# ----> 1 type(tweets)
#
# NameError: name 'tweets' is not defined

# %%
type(tweets[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-d2eba68f40d1> in <module>
# ----> 1 type(tweets[0])
#
# NameError: name 'tweets' is not defined

# %%
tweets[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-a09f3bb64705> in <module>
# ----> 1 tweets[0]
#
# NameError: name 'tweets' is not defined

# %%
help(tweets[0])

# %%
tweets[0].keys()

# %%
tweets[0]['text']

# %%
tweets[0]['created_at']

# %%
len(tweets)

# %%
tweets[len(tweets)-1]['text']

# %%
tweets[0]['user']

# %%
user = tweets[0]['user']
print('screen_name=%s, name=%s, location=%s' % (user['screen_name'], user['name'], user['location']))

# %%
# Who follows this person?
# https://dev.twitter.com/docs/api/1.1/get/followers/list
screen_name = user['screen_name']
response  = twitter.request('followers/list', {'screen_name': screen_name, 'count':200})
followers = [follower for follower in response]
        
print ('found %d followers for %s' % (len(followers), screen_name))
# See more about paging here: https://dev.twitter.com/docs/working-with-timelines

# %%
print(followers[0]['screen_name'])

# %%
# Get this person's timeline
timeline = [tweet for tweet in twitter.request('statuses/user_timeline',
                                                {'screen_name': screen_name,
                                                 'count': 200})]
print('got %d tweets for user %s' % (len(timeline), screen_name))

# %%
# Print the text.
print ('\n\n\n'.join(t['text'] for t in timeline))

# %%
# Count words
from collections import Counter  # This is just a fancy dict mapping from object->int, starting at 0.
counts = Counter()
for tweet in timeline:
    counts.update(tweet['text'].lower().split())
print('found %d unique terms in %d tweets' % (len(counts), len(timeline)))
counts.most_common(10)

# %%
# Sort by value, descending.
# See more about Python's lambda expressions:
# https://docs.python.org/2/tutorial/controlflow.html#lambda-expressions

sorted_counts = sorted(counts.items(), key=lambda x: x[1], reverse=True)

# %%
print ('\n'.join('%s=%d' % (term[0], term[1])  
                for term in sorted_counts[:10]))

# %% [markdown]
# <div class="alert alert-info">
#
#
#
# <br>
#
# **Twitter** suspended **realDonaldTrump** account on Twitter, so we should be getting an error
#
# <br>
#     https://blog.twitter.com/en_us/topics/company/2020/suspension.html
# <br>
#
# </div>
#
#
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Now lets collect data about few of the 2016 presidential candidates

# %%
#Create LOT (List-Of-Tuples) for 2016 Presidential Candidates

#Please note that due Twitter suspension of realDonaldTrump account on twitter, we can't access
# teh data for that account


LOT_presidentialCandidates = [('GovBillWeld', 'R'), 
                              ('AndrewYang', 'D'), 
                              ('TomSteyer', 'D'),
                              ('JohnDelaney', 'D'),
                              ('ewarren', 'D'),
                              ('WalshFreedom', 'R'),
                              ('PeteButtigieg', 'D'),
                              ('BernieSanders', 'D'),
                              ('GovernorBullock', 'D'),
                              ('JoeSestak', 'D'),
                              ('MichaelBennet', 'D'),
                              ('WayneMessam', 'D'),
                              ('amyklobuchar', 'D'),
                              ('KamalaHarris', 'D'),
                              ('MarkSanford', 'R'),
                              ('TulsiGabbard', 'D'),
                              ('mike_pence', 'R'),
                              ('marwilliamson', 'D'),
                              ('JulianCastro', 'D'),
                              ('CoryBooker', 'D'),
                              ('JoeBiden', 'D')]

#                              ('realDonaldTrump', 'R')]

# %% [markdown]
# <div class="alert alert-info">
#
#
#
# <br>
#
# **Twitter** suspended **realDonaldTrump** account on Twitter, so we should be getting an error
#
# <br>
# </div>

# %% [markdown]
# ### Lets see first realDonaldTrump  followers and Friends; we put a limit max 200 friends

# %%
# Lets see first realDonaldTrump Friends
# We put a limit max 200 friends


response = twitter.request('friends/list', {'screen_name': 'realDonaldTrump', 'count':200})

friends = [friend for friend in response]

# %% [markdown]
# <div class="alert alert-info">
#
# <br>
#
# Since we can't access the data for **realDonaldTrump** account,  we will proceed with **JoeBiden** account
#
#
#
# <br>
# </div>

# %%
# Lets see first JoeBiden Friends
# We put a limit max 200 friends


response = twitter.request('friends/list', {'screen_name': 'JoeBiden', 'count':200})

friends = [friend for friend in response]

# %%
friends

# %%
response  = twitter.request('followers/list', {'screen_name': 'JoeBiden', 'count':200})
followers = [follower for follower in response]

# %%
followers

# %% [markdown]
# ### Lets see how many friends for every candidate. We put a limit max 200 friends

# %%
import time

candidatesFriends={}

for candidate in  LOT_presidentialCandidates[:21]:
    response = twitter.request('friends/list', {'screen_name': candidate[0], 'count':200})
    print('response.status_code = ', response.status_code)
    if response.status_code == 429 :
            time.sleep(15*60) # sleep for 15 minutes twitter call limit reached
            response = twitter.request('friends/list', {'screen_name': candidate[0], 'count':200})
            print('response.status_code = ', response.status_code)
            
    friends = [r for r in response]
    print (candidate[0], '  has ', len(friends), ' friends')
    candidatesFriends[candidate[0]]=friends

# %% [markdown]
# ###  Sanity test: lets see who are JoeBiden friends

# %%
# Sanity test: lets see who are JoeBiden friends

for friend in candidatesFriends['JoeBiden']:
    print (friend['screen_name'])

# %% [markdown]
# ###  Who are the most popular friends by republicans (candidates)?

# %%
# Who are the most popular friends by republican party?


# separate candidates by party.
republicans = [candidate[0] for candidate in LOT_presidentialCandidates if candidate[1] == 'R']
democrats = [candidate[0] for candidate in LOT_presidentialCandidates if candidate[1] == 'D']
print('%d republicans, %d democrats' % (len(republicans), len(democrats)))


print('popular Republican friends:')

republican_counts = Counter()

for candidate in  LOT_presidentialCandidates: 
    if candidate[0] in republicans:
        for friend in candidatesFriends[candidate[0]]:
            republican_counts[friend['screen_name']] += 1
 
print (republican_counts.most_common(3))

# %% [markdown]
# # Requirement #1: which friend is followed by the most number of candidates?

# %% [markdown]
# # Requirement #2: Get the top 10 list of popular Democrats(candidates) friends

# %% [markdown]
# # Requirement #3: Get JoeBiden's tweets  and create a table that has the numbers for the tweets where he mentioned any of the  following terms (create a table that has every term listed below and its frequency in his tweets)
# > 1. Tarrif
# > 2. New Jobs
# > 3. Taxes
# > 4. Fake News
# > 5. Nuclear
# > 6. Russia
# > 7. China
# > 8. North Korea
# > 9. Iran
# > 10. No Collusion

# %% [markdown]
# # Requirement #4: Identify 5 more high-frequency terms in JoeBiden tweets that are not listed in Requirement #3

# %% [markdown]
# # Requirement #5: Perform Sentiment Analysis (Positive, Negative, or Neutral) of every candidate's position (based on the candidate's tweets) toward Jerome H. Powell
#
# ### Jerome H. Powell took office as Chair of the Board of Governors of the Federal Reserve System on February 5, 2018  __[Federal Reserve](https://www.federalreserve.gov/aboutthefed/bios/board/powell.htm)__
#
#
# Few online resources that you could use for reading if you don't have knowledge of sentiment analysis/NLP:
# 1. https://www.freecodecamp.org/news/how-to-build-a-twitter-sentiments-analyzer-in-python-using-textblob-948e1e8aae14/
# 2. https://www.geeksforgeeks.org/twitter-sentiment-analysis-using-python/
# 3. https://textblob.readthedocs.io/en/dev/quickstart.html#sentiment-analysis
# 4. https://textblob.readthedocs.io/en/dev/api_reference.html#textblob.blob.TextBlob

# %% [markdown]
# ![image.png](attachment:image.png)
